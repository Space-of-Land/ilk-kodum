# %%
print("Hallo,\nHow are you.")
print("Hallo \t How are you.")
print("My name is Lucky")
print(("my name is {1},i am {0}").format(25,"Lucky"))
sayi=10
print(sayi)
sayi=sayi + 2
print(sayi)
print((2+3)+(2*4))
hava_durumu="yagisli"
if hava_durumu=="yagisli":
    print("zontiqi al!")
    hava_durumu="qarli"
    if hava_durumu=="qarli":
        print("sarpi al !")
    elif hava_durumu=="yagisli":
        print("zontiqi al!")

    else:
        print("problem deyil.")
yas=15
if yas > 18 :
    print("salam")
else:
    print("Sen bura aid deyilsen")
    

    liste=["a","b","c"]
    hedef_harf="d"
    if hedef_harf in liste:
        print("buldum")
    else:
        liste.append(hedef_harf)
        print("liste ekledim")
        print("Güncel liste{}".format(liste))
# Out:
# Hallo,
# How are you.
# Hallo 	 How are you.
# My name is Lucky
# my name is Lucky,i am 25
# 10
# 12
# 13
# zontiqi al!
# sarpi al !
# Sen bura aid deyilsen
# liste ekledim
# Güncel liste['a', 'b', 'c', 'd']

# %%
if (hedef_harf in liste) and (hedef_harf== liste[0]):
    print("buldum ve ilk harf konumunda")
elif hedef_harf in liste:
    print("buldum amma ilk konumda deyil")
else:
    liste.append(hedef_harf)
    print("liste ekledim")
    print("Güncel liste{}".format(liste))
# Out:
# buldum amma ilk konumda deyil

# %%
meyveler=["alma","armud","banan"]
for meyve in meyveler:
    print(meyve)
# Out:
# alma
# armud
# banan

# %%
meyve_sayisi = 0
for meyve in meyveler:
    meyve_sayisi = meyve_sayisi + 1
    print(meyve_sayisi,meyve)
# Out:
# 1 alma
# 2 armud
# 3 banan

# %%
istirakci_siyahisi = ["das demir","ala göz","uzun qulaq","al yanaq"]

for qonaq in istirakci_siyahisi:
    print(qonaq)
# Out:
# das demir
# ala göz
# uzun qulaq
# al yanaq

# %%
#ad = istirakci_siyahisi [0].split()[0]
#soyad = istirakci_siyahisi [0].split()[1]
#print(ad)
#print(soyad)

# %%
qonaq_sayi = 0
for qonaq in istirakci_siyahisi:
    qonaq_sayi = qonaq_sayi + 1
    ad, soyad = qonaq.split()[0], qonaq.split()[1]

    print("{0}. qonagin adi {1} ve soyadi {2}".format(qonaq_sayi,ad,soyad))
# Out:
# 1. qonagin adi das ve soyadi demir
# 2. qonagin adi ala ve soyadi göz
# 3. qonagin adi uzun ve soyadi qulaq
# 4. qonagin adi al ve soyadi yanaq

# %%
moderator = "uzun qulaq"
qonaq_sayi = 0
moderator_sayi = 0
for qonaq in istirakci_siyahisi:
    
    

    ad,soyad = qonaq.split ()[0], qonaq.split ()[1]
    
    if (qonaq == moderator):
        moderator_sayi = moderator_sayi + 1
        print("{0}. moderatorun adi {1} ve soyadi {2}". format (moderator_sayi,ad,soyad))
    else:
        qonaq_sayi += 1
        print("{0}. qonagin adi {1} ve soyadi {2}". format (qonaq_sayi, ad, soyad))
# Out:
# 1. qonagin adi das ve soyadi demir
# 2. qonagin adi ala ve soyadi göz
# 1. moderatorun adi uzun ve soyadi qulaq
# 3. qonagin adi al ve soyadi yanaq

# %%
tupl = (1,2,3,4,)
for sayi in tupl:

 print (sayi)
# Out:
# 1
# 2
# 3
# 4

# %%
liste = [[1,2],[3,4],[5,6]]
for x,y in liste:
    print(x*y)
# Out:
# 2
# 12
# 30

# %%
istifadeci1 = {
    "ad":"Naz",
    "soyad":"yagcioglu"
}
istifadeci1.items()
for k,v in istifadeci1.items():
    print("key: {} \t value:{}".format(k,v))
# Out:
# key: ad 	 value:Naz
# key: soyad 	 value:yagcioglu
