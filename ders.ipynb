# %%
print("Hallo World")
print(2026-1987)
dict1={
    "ad":"Mesut",
    "yas":37,
   # "lokasiyon":"berlin"
}
print(dict1)
dict2={
    "ad":"Mesut",
    "yas":"37",
    "lokasyon":{
        "doğduğu_yer":"Istanbul",
        "Yasadigi_yer":"Berlin"
    }}
print(dict2)
print(dict2["yas"])
print(dict2.get("ad"))
print(dict2["lokasyon"]["Yasadigi_yer"])
print(dict2["lokasyon"],dict2["lokasyon"]["Yasadigi_yer"])
print(dict2.keys())
print(dict2.values())
print(dict2.items())
# Out:
# Hallo World
# 39
# {'ad': 'Mesut', 'yas': 37}
# {'ad': 'Mesut', 'yas': '37', 'lokasyon': {'doğduğu_yer': 'Istanbul', 'Yasadigi_yer': 'Berlin'}}
# 37
# Mesut
# Berlin
# {'doğduğu_yer': 'Istanbul', 'Yasadigi_yer': 'Berlin'} Berlin
# dict_keys(['ad', 'yas', 'lokasyon'])
# dict_values(['Mesut', '37', {'doğduğu_yer': 'Istanbul', 'Yasadigi_yer': 'Berlin'}])
# dict_items([('ad', 'Mesut'), ('yas', '37'), ('lokasyon', {'doğduğu_yer': 'Istanbul', 'Yasadigi_yer': 'Berlin'})])
